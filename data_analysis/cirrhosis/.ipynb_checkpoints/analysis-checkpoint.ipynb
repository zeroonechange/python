# %%
import numpy as np
import pandas as pd

data = pd.read_excel('2015_75_people.xlsx')
data.head()
# Out:
#                   送检日期   姓名  Unnamed: 2 性别  Unnamed: 4    年龄  民族       病历号  \
# 0  2015-01-05 00:00:00  张钦奎        40.0  男         0.0  17.0  汉族  590762.0
# 1  2015-01-31 00:00:00  唐邦武        40.0  男         2.0  48.0  汉族  583479.0
# 2  2015-02-03 00:00:00   刘亮        40.0  男         0.0  28.0  汉族  596468.0
# 3  2015-02-11 00:00:00   杨华        32.0  女         0.0  28.0  汉族  597496.0
# 4  2015-02-12 00:00:00  伍快秀        32.0  女         2.0  49.0  汉族  597024.0
#
#           临床诊断    肝活检结果 ...     血小板  INR相关  INR  脾脏厚度    PT     APRI值  \
# 0         黄疸查因      NaN ...   296.0    NaN    无   NaN   NaN  0.001605
# 1  病毒性肝炎乙型慢性重度     G1S2 ...   202.0    0.0  0.9  32mm   NaN  0.039233
# 2  病毒性肝炎乙型慢性轻度    G1S1。 ...   210.0    0.0  0.8  32mm   NaN  0.005595
# 3    病毒性肝炎乙型慢性    G1S1。 ...   181.0    NaN  NaN  43mm  11.2  0.005007
# 4  病毒性肝炎乙型慢性轻度    G4S4。 ...   143.0    NaN  NaN  35mm  13.0  0.012238
#
#            FIB4  AP指数  CDS评分 活检简化
# 0     15.277027   0.0    NaN    无
# ...

# %%
cleandata = data.iloc[:, 22:]
cleandata.tail()
# Out:
#        APRI值        FIB4  AP指数  CDS评分 活检简化
# 76  0.004202  310.588235   3.0    3.0    有
# 77  0.002794  113.105882   5.0    4.0   显著
# 78  0.008422  407.489362   5.0    6.0    有
# 79  0.005058  189.364162   3.0    5.0    无
# 80       NaN         NaN   NaN    NaN  NaN

# %%
mapping = {'APRI值' : 'APRI',     'AP指数' : 'AP',  'CDS评分' : 'CDS',  '活检简化' : 'result' }
cleandata.rename(columns=mapping, inplace=True)
cleandata.tail()
# Out:
#         APRI        FIB4   AP  CDS result
# 76  0.004202  310.588235  3.0  3.0      有
# 77  0.002794  113.105882  5.0  4.0     显著
# 78  0.008422  407.489362  5.0  6.0      有
# 79  0.005058  189.364162  3.0  5.0      无
# 80       NaN         NaN  NaN  NaN    NaN

# %%
cleandata.dropna(inplace=True)

cleandata['result'].unique()
# Out:
# array(['显著', '有', '肝硬化', '无'], dtype=object)

# %%
mapping_re = {'无': 0, '有': 50, '显著': 75, '肝硬化' : 100}
f = lambda x: mapping_re.get(x)
#cleandata['result'].apply(f)
cleandata['result'] = cleandata['result'].map(f)

# %%
cleandata.tail()
# Out:
#         APRI        FIB4   AP  CDS  result
# 75  0.006783  339.906977  7.0  6.0      50
# 76  0.004202  310.588235  3.0  3.0      50
# 77  0.002794  113.105882  5.0  4.0      75
# 78  0.008422  407.489362  5.0  6.0      50
# 79  0.005058  189.364162  3.0  5.0       0

# %%
'''pdata = cleandata.pivot_table('result', index='AP', columns=['CDS'])
# %matplotlib notebook
pdata.plot()'''
cleandata.AP.cov(cleandata.result)
# Out:
# 4.9751243781094576

# %%
cleandata.CDS.cov(cleandata.result)
# Out:
# -4.4719583898688384

# %%
cleandata.corr()
# Out:
#             APRI      FIB4        AP       CDS    result
# APRI    1.000000  0.985231  0.246425  0.211805 -0.143185
# FIB4    0.985231  1.000000  0.192537  0.147510 -0.167396
# AP      0.246425  0.192537  1.000000  0.744558  0.092723
# CDS     0.211805  0.147510  0.744558  1.000000 -0.142036
# result -0.143185 -0.167396  0.092723 -0.142036  1.000000

# %%
cleandata.cov()
# Out:
#               APRI          FIB4           AP          CDS        result
# APRI      0.000945  6.426174e+02     0.016118     0.008129     -0.111014
# FIB4    642.617366  4.501318e+08  8690.891869  3907.110499 -89567.698930
# AP        0.016118  8.690892e+03     4.526459     1.977612      4.975124
# CDS       0.008129  3.907110e+03     1.977612     1.558571     -4.471958
# result   -0.111014 -8.956770e+04     4.975124    -4.471958    636.024423

# %%
import matplotlib  
import matplotlib.pyplot as plt
# %matplotlib notebook
'''x1 = cleandata['AP']
x2 = cleandata['CDS']
y = cleandata['result']
plt.scatter(x1, y, s = 15)
plt.scatter(x2, y, s = 15)
plt.show()'''
# Out:
# <img src="data:image/png;base64,..." width="640">
