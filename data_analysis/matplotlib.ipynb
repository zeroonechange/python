# %%
# %matplotlib notebook   # 这句话使得可以在jupyter notebook中绘图 
import matplotlib.pyplot as plt
import numpy as np
data = np.arange(10)
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)  # 画三张图
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')  # 画单张图片
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)    # AxesSubplot 对象
ax2 = fig.add_subplot(2,2,2)    # AxesSubplot 对象
ax3 = fig.add_subplot(2,2,3)    # AxesSubplot 对象
plt.plot(np.random.randn(50).cumsum(), 'k--')  # 如果没有指定  默认是在最后一个添加的subplot上绘图   k-- 是线性选项  黑色虚线
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)     
ax2 = fig.add_subplot(2,2,2)     
ax3 = fig.add_subplot(2,2,3)    
plt.plot(np.random.randn(50).cumsum(), 'k--') 
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)  # 直方图  hist
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))  # 散点图
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes = plt.subplots(2, 3)   # 创建一个新的Figure，并返回一个含有已创建的subplot对象的NumPy数组
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 例如上面的图， 子图之间默认都是有间距的
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='r', alpha=0.6)   # 颜色有 g=green, k=black, r=red
    plt.subplots_adjust(wspace=0, hspace=0)  # 通过这个动作把间距给抹去了
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from numpy.random import randn
#plt.plot(randn(30).cumsum(), 'ko--')  
plt.plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='*')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k--', drawstyle='steps-post', label='steps-post')  # 是直方图     steps-post 转化
plt.legend(loc='best')         #指明线
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = np.random.randn(1000).cumsum()
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ticks = ax.set_xticks([0, 250, 500, 750, 1000])    # 刻度范围
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')  # 刻度标签样式
ax.set_title('hello chicago!')  # 顶部标题
ax.set_xlabel('Stages')         # 底部标题   轴标签
#prop = {'title': 'My first matplotlib plot', 'xlabel': 'Stages'}   标签互换效果
#ax.set(**prop)
ax.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 图例  legend
from numpy.random import randn
fig = plt.figure(); ax=fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')
ax.legend(loc='best')  # "best" 会选择最不碍事的位置。要从图例中去除一个或多个元素，不传入label或传入label='nolegend'即可。
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from datetime import datetime
import pandas as pd
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('examples/spx.csv', index_col =0, parse_dates = True)
spx = data['SPX']
spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),   # 与点的高间距 
               xytext=(date, spx.asof(date) + 225),      # 箭头的高度
               arrowprops=dict(facecolor='black', headwidth=4, width=2, headlength=4),
               horizontalalignment='left', verticalalignment='top')
    
# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])
ax.set_title('Important dates in the 2008-2009 financial crisis')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 添加一个图形
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circle = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color='g', alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circle)
ax.add_patch(pgon)  # 由块patch组装而成的
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 将图表保存到文件
# 两个重要的选项是dpi（控制“每英寸点数”分辨率）和bbox_inches（可以剪除当前图表周围的空白部分）
# 要得到一张带有最小白边且分辨率为400DPI的PNG图片    plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

#并非一定要写入磁盘，也可以写入任何文件型的对象，比如BytesIO

# %%
# 使用rc方法   管理图像大小、subplot边距、配色方案、字体大小、网格类型等
# plt.rc('figure', figsize=(10, 10))
"""
font_options = {'family' : 'monospace',
                'weight' : 'bold',
                'size'   : 'small'}
plt.rc('font', **font_options)
"""

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
